# %%
import pandas as pd

# %%
e_content_meta = pd.read_csv('data/9기 최종 전달 데이터/최종 전달 데이터/e_content_meta.csv')
e_content_meta
# Out:
#                mcode                   l_title  \
# 0       T0ME10U28009  (두 자리 수)-(한 자리 수)① 색연필 셈
# 1       T0ME20U27002     (두 자리 수)-(한 자리 수)② 기차
# 2       T9ME12U05043         (몇) + (몇) = (십 몇)
# 3       T9ME12U03073             (몇십 몇)－(몇십 몇)
# 4       T0ME12U57003               (몇십몇)+(몇십몇)
# ...              ...                       ...
# 105007  T0ME22U04105      하루의 시간 알아보기, 달력 알아보기
# 105008  T0ME12U04107              한 자리 세 수의 덧셈
# 105009  T9ME12U06097           핵심 개념으로 단원 정리하기
# 105010  T0ME21U01013            핵심 문제로 단원 정리하기
# 105011  A9ME21004019               활동학습으로 복습하기
#
#                               unique_content_nm    leccode        u_title  \
# 0       (두 자리 수)-(한 자리 수)① 색연필 셈 (T0ME10U28009)  T0ME10U28          3. 뺄셈
# 1          (두 자리 수)-(한 자리 수)② 기차 (T0ME20U27002)  T0ME20U27          3. 뺄셈
# 2              (몇) + (몇) = (십 몇) (T9ME12U05043)  T9ME12U05  5. 덧셈과 뺄셈 (2)
# 3                  (몇십 몇)－(몇십 몇) (T9ME12U03073)  T9ME12U03  3. 덧셈과 뺄셈 (1)
# ...

# %%
df1 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202401.parquet')
df2 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202402.parquet')

df3 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202403.parquet')

df4 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202404.parquet')

df5 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202405.parquet')

df6 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202406.parquet')

df7 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202407.parquet')

df8 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202408.parquet')

df9 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202409.parquet')

df10 = pd.read_parquet('data\\9기 최종 전달 데이터\최종 전달 데이터\\tbl_app_testhisdtl\\tbl_app_testhisdtl_202410.parquet')

# %%
df1
# Out:
#                                         UserID         mCode  No  QuizCode  \
# 0         4f672b16-c7d3-40f4-b6d7-027f1bb15331  T0EE20U01121   1  30126926
# 1         4f672b16-c7d3-40f4-b6d7-027f1bb15331  T0KE20U07064   1  30130973
# 2         4f672b16-c7d3-40f4-b6d7-027f1bb15331  T0KE31U01001   1  30015977
# 3         4f672b16-c7d3-40f4-b6d7-027f1bb15331  T0KE31U01001   2  30015978
# 4         4f672b16-c7d3-40f4-b6d7-027f1bb15331  T0KE31U01001   3  30015979
# ...                                        ...           ...  ..       ...
# 22386822  3a01cf84-58e3-43c4-a5ff-ffffed905e79  T0ME31U04049   3  30016517
# 22386823  3a01cf84-58e3-43c4-a5ff-ffffed905e79  T0ME31U04049   4  30016524
# 22386824  3a01cf84-58e3-43c4-a5ff-ffffed905e79  T0ME31U04049   5  30016505
# 22386825  3a01cf84-58e3-43c4-a5ff-ffffed905e79  T0PE30U01357   1  30138311
# 22386826  3a01cf84-58e3-43c4-a5ff-ffffed905e79  T0SE30U01132   1  30076213
#
#           Answer Correct             CreDate LM_IDX
# ...

# %%
df9
# Out:
#                                         userid         mcode  no  quizcode  \
# 0         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   2  30128602
# 1         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   3  30128603
# 2         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   4  30128604
# 3         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   5  30128605
# 4         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U54001   1  30128611
# ...                                        ...           ...  ..       ...
# 23170269  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   2  30128592
# 23170270  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   3  30128593
# 23170271  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   4  30128594
# 23170272  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   5  30128595
# 23170273  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   1  30128601
#
#                                        answer correct  \
# ...

# %%
dataframes = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]

# %%
reference_columns = set(dataframes[0].columns)

# %%
def check_columns(df_list, ref_set):
    for idx, df in enumerate(dataframes):
        current_columns = set(df.columns)
        if current_columns != reference_columns:
            print(f"DataFrame {idx + 1}의 컬럼이 다릅니다.")
            print(f"기준 컬럼: {sorted(reference_columns)}")
            print(f"현재 컬럼: {sorted(current_columns)}")
    print('모든 컬럼명이 일치합니다!')

check_columns(dataframes, reference_columns)
# Out:
# DataFrame 9의 컬럼이 다릅니다.
# 기준 컬럼: ['Answer', 'Correct', 'CreDate', 'LM_IDX', 'No', 'QuizCode', 'UserID', 'mCode']
# 현재 컬럼: ['answer', 'correct', 'credate', 'lm_idx', 'mcode', 'mm', 'no', 'quizcode', 'userid', 'yyyy']
# DataFrame 10의 컬럼이 다릅니다.
# 기준 컬럼: ['Answer', 'Correct', 'CreDate', 'LM_IDX', 'No', 'QuizCode', 'UserID', 'mCode']
# 현재 컬럼: ['answer', 'correct', 'credate', 'lm_idx', 'mcode', 'mm', 'no', 'quizcode', 'userid', 'yyyy']
# 모든 컬럼명이 일치합니다!

# %%
df9 = df9.rename(columns={'answer':'Answer', 'correct':'Correct', 'credate':'CreDate', 'lm_idx':'LM_IDX', 'mcode':'mCode','no':'No', 'quizcode':'QuizCode', 'userid':'UserID'})
df10 = df10.rename(columns={'answer':'Answer', 'correct':'Correct', 'credate':'CreDate', 'lm_idx':'LM_IDX', 'mcode':'mCode','no':'No', 'quizcode':'QuizCode', 'userid':'UserID'})

# %%
dataframes = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]

# %%
check_columns(dataframes, reference_columns)
# Out:
# DataFrame 9의 컬럼이 다릅니다.
# 기준 컬럼: ['Answer', 'Correct', 'CreDate', 'LM_IDX', 'No', 'QuizCode', 'UserID', 'mCode']
# 현재 컬럼: ['Answer', 'Correct', 'CreDate', 'LM_IDX', 'No', 'QuizCode', 'UserID', 'mCode', 'mm', 'yyyy']
# DataFrame 10의 컬럼이 다릅니다.
# 기준 컬럼: ['Answer', 'Correct', 'CreDate', 'LM_IDX', 'No', 'QuizCode', 'UserID', 'mCode']
# 현재 컬럼: ['Answer', 'Correct', 'CreDate', 'LM_IDX', 'No', 'QuizCode', 'UserID', 'mCode', 'mm', 'yyyy']
# 모든 컬럼명이 일치합니다!

# %%
df9.drop(['mm','yyyy'], axis=1, inplace=True)
df10.drop(['mm','yyyy'], axis=1, inplace=True)

# %%
df10
# Out:
#                                         UserID         mCode  No  QuizCode  \
# 0         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   2  30128602
# 1         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   3  30128603
# 2         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   4  30128604
# 3         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   5  30128605
# 4         aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U54001   1  30128611
# ...                                        ...           ...  ..       ...
# 23170269  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   2  30128592
# 23170270  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   3  30128593
# 23170271  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   4  30128594
# 23170272  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53003   5  30128595
# 23170273  aa94b664-d54b-4194-a080-91452e71d1ba  T0SE52U53004   1  30128601
#
#                                        Answer Correct  \
# ...

# %%
mcode_list = e_content_meta["mcode"].unique()
mcode_list
# Out:
# array(['T0ME10U28009', 'T0ME20U27002', 'T9ME12U05043', ...,
#        'T1ME22U05041', 'T1ME12U02023', 'T1ME12U10005'], dtype=object)

# %%
filtered_dataframes = [df[df["mCode"].isin(mcode_list)] for df in dataframes]

# %%
filtered_dataframes
# Out:
# [                                        UserID         mCode  No  QuizCode  \
#  19        f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   1  30140110
#  20        f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   2  30140115
#  21        f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   3  30140113
#  22        f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   4  30140114
#  23        f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   5  30140044
#  ...                                        ...           ...  ..       ...
#  22386798  1a851549-0ce5-43da-b73c-ffff1117f116  T1ME11U05004   1  30140206
#  22386799  1a851549-0ce5-43da-b73c-ffff1117f116  T1ME11U05004   2  30140070
#  22386800  1a851549-0ce5-43da-b73c-ffff1117f116  T1ME11U05004   3  30140207
#  22386801  1a851549-0ce5-43da-b73c-ffff1117f116  T1ME11U05004   4  30140208
#  22386802  1a851549-0ce5-43da-b73c-ffff1117f116  T1ME11U05004   5  30140209
#
# ...

# %%
combined_dataframe = pd.concat(filtered_dataframes, ignore_index=True)

# %%
combined_dataframe
# Out:
#                                         UserID         mCode  No  QuizCode  \
# 0         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   1  30140110
# 1         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   2  30140115
# 2         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   3  30140113
# 3         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   4  30140114
# 4         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   5  30140044
# ...                                        ...           ...  ..       ...
# 20130484  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02014   8  30159330
# 20130485  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02014   9  30159331
# 20130486  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02034   1  30159331
# 20130487  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02034   2  30159316
# 20130488  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02034   3  30159317
#
#                       Answer Correct                  CreDate LM_IDX
# ...

# %%
output_file_path = "./data/filtered_combined_user_data.csv"
combined_dataframe.to_csv(output_file_path, index=False)
print(f"필터링되고 병합된 데이터가 '{output_file_path}'에 저장되었습니다.")
# Out:
# 필터링되고 병합된 데이터가 './data/filtered_combined_user_data.csv'에 저장되었습니다.

# %%
combined_dataframe
# Out:
#                                         UserID         mCode  No  QuizCode  \
# 0         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   1  30140110
# 1         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   2  30140115
# 2         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   3  30140113
# 3         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   4  30140114
# 4         f70467a4-7bc5-4bda-99d4-0280065daa65  T1ME11U01001   5  30140044
# ...                                        ...           ...  ..       ...
# 20130484  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02014   8  30159330
# 20130485  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02014   9  30159331
# 20130486  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02034   1  30159331
# 20130487  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02034   2  30159316
# 20130488  318bc764-d338-4a58-8b0c-913fb1d6d042  T1ME22U02034   3  30159317
#
#                       Answer Correct                  CreDate LM_IDX
# ...
